# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_pickle('Extracted_Information.dat')
gdp_historical = pd.read_csv('GDPhistoricaldata.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-6fba60b7afb0> in <module>
# ----> 1 data = pd.read_pickle('Extracted_Information.dat')
#       2 gdp_historical = pd.read_csv('GDPhistoricaldata.csv')
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression)
#     167     if not isinstance(fp_or_buf, str) and compression == "infer":
#     168         compression = None
# --> 169     f, fh = get_handle(fp_or_buf, "rb", compression=compression, is_text=False)
#     170
#     171     # 1) try standard library Pickle
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     497         else:
#     498             # Binary mode
# --> 499             f = open(path_or_buf, mode)
# ...
